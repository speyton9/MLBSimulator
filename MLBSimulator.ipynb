# %%
import pandas as pd
import numpy as np
import re
import random

# %%
#Import CSV
df = pd.read_csv(r'C:\\Users\\Steven\\Desktop\\DFS\\MLB\\Stats.csv', delimiter=',')

# %%
#Place in in list
stats = [list(row) for row in df.values]

#FP Dict for All Results to export to CSV
gameFP = {}
z = 0
for row in stats:
    key = row[1]
    gameFP[key] = []
    z+=0
scores = {}
tm = df.Team.unique()
#Shortcut to change number of Sims
ts = round(2800/(int(len(tm))/2))
print(ts)
zyx = 0
for row in tm:
    key = row[0:]
    scores[key] = 0
    zyx +=1
#League Averages of Pitcher Events
Aso = 0.2290494751
Afo = 0.4635371767
Abb = 0.08231358994
Ahbp = 0.01079069081
Asing = 0.1395328868
Adbl = 0.04299636773
Atrp = 0.003488901188
Ahr = 0.02802606582
#List of Unique Games
games = df.Game.unique()
#List of Unique Names
names = df.Nickname.unique()
#Begin Loop to sim all games ts times
sim = 0
while sim < ts:
    j=0
    #Loop through each game
    while j < len(games):
        g = []
        i = 0
        #Place Game n in list g
        while i < len(stats):
            if stats[i][6] == games[j]:
                g.append(stats[i])
            i+=1
        #home team
        h = []
        #home team
        a = []
        k = 0
        #Split home and away teams
        while k < len(g):
            if g[k][3] == g[k][5]:
                h.append(g[k])
                k+=1
            else:
                a.append(g[k])
                k+=1
        hp = []
        ap = []
        hstart = []
        astart = []
        x = 0
        #Place home pitcher in own list, remove from previous
        while x < len(h):
            if h[x][2] == 'P':
                hp.append(h[x])
                h.pop(x)
                #if len(hp) == 1:
                    #break
            x+=1
        y = 0
        #Place away pitcher in own list, remove from previous
        while y < len(a):
            if a[y][2] == 'P':
                ap.append(a[y])
                a.pop(y)
                #if len(ap) == 1:
                    #break
            y+=1
        print(hp)
        print(ap)
        Hdict = {}
        Adict = {}
        #Place home hitters in dict
        for row in h:
            key = row[0]
            Hdict[key] = row[1:]
        #Place away hitters in dict
        for row in a:
            key = row[0]
            Adict[key] = row[1:]
        inning = 0
        #Pitcher List
        hsp = []
        asp = []
        hsp.append(hp[0][1])
        asp.append(ap[0][1])
        #Scoreboard
        home = 0
        away= 0
        #Summary of FP for each player
        sumFP = {}
        t = 0
        for row in stats:
            key = row[1]
            sumFP[key] = 0
            t+=0
        #Batting Order start point
        abo = 0
        hbo = 0
        #Number of batters faced for pulling
        lhbo = 0
        labo = 0
        #Home score when pitcher is pulled
        hss = {}
        hss['home'] = 0
        hss['away'] = 0
        hqs = 0
        #Away score when pitcher is pulled
        ass = {}
        ass['home'] = 0
        ass['away'] = 0
        aqs = 0
        #start game
        while inning < 18:
            #Top of the inning
            if inning%2 == 0:
                print('-------------------------------------Top-Of-The-'+str((inning/2)+1)+'-----------------------------')
                b = 0
                bb = 0
                bbb = 0
                out = 0
                #inning score --- if exceeds 4, pull pitcher mid inning
                ins = 0
                while out < 3:
                    #Flips Batting Order when last hitter is reached
                    if abo == 9:
                        abo = 0
                    while abo < 9:
                        if out == 3:
                            break
                        #SO prob
                        so = (((Adict[abo+1][6])*hp[0][7])/Aso)/((((Adict[abo+1][6])*hp[0][7])/Aso)+(((1-Adict[abo+1][6])*(1-hp[0][7]))/(1-Aso)))
                        #other out prob
                        ot = (((Adict[abo+1][7])*hp[0][8])/Afo)/((((Adict[abo+1][7])*hp[0][8])/Afo)+(((1-Adict[abo+1][7])*(1-hp[0][8]))/(1-Afo)))
                        #BB prob
                        walk = (((Adict[abo+1][8])*hp[0][9])/Abb)/((((Adict[abo+1][8])*hp[0][9])/Abb)+(((1-Adict[abo+1][8])*(1-hp[0][9]))/(1-Abb)))
                        #HBP prob
                        hbp = (((Adict[abo+1][9])*hp[0][10])/Ahbp)/((((Adict[abo+1][9])*hp[0][10])/Ahbp)+(((1-Adict[abo+1][9])*(1-hp[0][10]))/(1-Ahbp)))
                        #sing prob
                        sing = (((Adict[abo+1][10])*hp[0][11])/Asing)/((((Adict[abo+1][10])*hp[0][11])/Asing)+(((1-Adict[abo+1][10])*(1-hp[0][11]))/(1-Asing)))
                        #dbl prob
                        dbl = (((Adict[abo+1][11])*hp[0][12])/Adbl)/((((Adict[abo+1][11])*hp[0][12])/Adbl)+(((1-Adict[abo+1][11])*(1-hp[0][12]))/(1-Adbl)))
                        #triple prob
                        trp = (((Adict[abo+1][12])*hp[0][13])/Atrp)/((((Adict[abo+1][12])*hp[0][13])/Atrp)+(((1-Adict[abo+1][12])*(1-hp[0][13]))/(1-Atrp)))
                        #HR prob
                        hr = (((Adict[abo+1][13])*hp[0][14])/Ahr)/((((Adict[abo+1][13])*hp[0][14])/Ahr)+(((1-Adict[abo+1][13])*(1-hp[0][14]))/(1-Ahr)))
                        #Total not equal to one all hitters, attempt to smooth this out --- If not some hitters HR rate doubles
                        tot = (so + ot + walk + hbp + sing + dbl + trp + hr)
                        err = ((1 - tot)/8)
                        so = (err+so)
                        ot = (err+ot)
                        walk = (err+walk)
                        hbp = (err+hbp)
                        sing = (err+sing)
                        dbl = (err+dbl)
                        trp = (err+trp)
                        hr = (err+hr)
                        onBase = random.uniform(0,1)
                        print(hp[0][1])
                        print('Home: '+str(home)+' Away: '+str(away))
                        print('1B: '+str(b)+' 2B: '+str(bb)+' 3B: '+str(bbb))
                        print('Out: '+str(out))
                        print('abo:'+ str(abo))
                        if onBase <= so:
                            sumFP[hp[0][1]]+=4
                            out+=1
                            #abo+=1
                            print('---------------------SO---------------------')
                        elif onBase <= (so + ot):
                            sumFP[hp[0][1]]+=1
                            out+=1
                            #abo+=1
                            print('---------------------Batter Out---------------------')
                            if b > 0:
                                if out < 2:
                                    if onBase <= (so + .04):
                                        sumFP[hp[0][1]]+=1
                                        out+=1
                                        b = 0
                                        if bbb > 0:
                                            sumFP[Adict[bbb][0]]+=3.2
                                            sumFP[hp[0][1]]+=-3
                                            bbb = 0
                                            ins+=1
                                            away+=1
                                        bbb = bb
                                        bb = 0
                                        print('---------------------Double Play---------------------')
                        elif onBase <= (so + ot + walk):
                            sumFP[Adict[abo+1][0]]+=3
                            print('---------------------Walk---------------------')   
                            if b > 0:
                                if bb > 0:
                                    if bbb > 0:
                                        sumFP[Adict[abo+1][0]]+=3.5
                                        sumFP[Adict[bbb][0]]+=3.2
                                        sumFP[hp[0][1]]+=-3
                                        bbb = bb
                                        ins+=1
                                        away+=1
                                    else:
                                        bbb = bb
                                else:
                                    bbb = bb
                                bb = b
                                b = abo+1
                            else:
                                b = abo+1
                        elif onBase <= (so + ot + walk + hbp):
                            sumFP[Adict[abo+1][0]]+=3
                            print('---------------------HBP---------------------')   
                            if b > 0:
                                if bb > 0:
                                    if bbb > 0:
                                        sumFP[Adict[abo+1][0]]+=3.5
                                        sumFP[Adict[bbb][0]]+=3.2
                                        sumFP[hp[0][1]]+=-3
                                        bbb = bb
                                        ins+=1
                                        away+=1
                                    else:
                                        bbb = bb
                                else:
                                    bbb = bb
                                bb = b
                                b = abo+1
                            else:
                                b = abo+1
                        elif onBase <= (so + ot + walk + hbp + sing):
                            sumFP[Adict[abo+1][0]]+=3
                            #Runners on base advance one or 2+ bags
                            adv = random.uniform(0,1)
                            if bbb > 0:
                                sumFP[Adict[bbb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                away+=1
                            if bb > 0:
                                if adv > Adict[bb][15]:
                                    sumFP[Adict[bb][0]]+=3.2
                                    sumFP[Adict[abo+1][0]]+=3.5
                                    sumFP[hp[0][1]]+=-3
                                    bb = 0
                                    ins+=1
                                    away+=1
                                else:
                                    bbb = bb
                                    bb = 0
                            if b > 0:
                                if bbb > 0:
                                    bb = b
                                    b = 0
                                elif adv > Adict[b][15]:
                                    bbb = b
                                    b = 0
                                else:
                                    bb = b
                                    b = 0
                            b = abo+1
                            print('---------------------Single---------------------')
                        elif onBase <= (so + ot + walk + hbp + sing + dbl):
                            sumFP[Adict[abo+1][0]]+=6
                            #Runners on base advance one or 2+ bags
                            adv = random.uniform(0,1)
                            if bbb > 0:
                                sumFP[Adict[bbb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                away+=1
                            if bb > 0:
                                sumFP[Adict[bb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bb = 0
                                ins+=1
                                away+=1
                            if b > 0:
                                if adv > (Adict[b][15] * 1.15):
                                    sumFP[Adict[b][0]]+=3.2
                                    sumFP[Adict[abo+1][0]]+=3.5
                                    sumFP[hp[0][1]]+=-3
                                    b = 0
                                    ins+=1
                                    away+=1
                                else:
                                    bbb = b
                                    b = 0
                            bb = abo+1
                            print("---------------------2B---------------------")
                        elif onBase <= (so + ot + walk + hbp + sing + dbl + trp):
                            sumFP[Adict[abo+1][0]]+=9
                            if bbb > 0:
                                sumFP[Adict[bbb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                away+=1
                            if bb > 0:
                                sumFP[Adict[bb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bb = 0
                                ins+=1
                                away+=1
                            if b > 0:
                                sumFP[Adict[b][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                b = 0
                                ins+=1
                                away+=1
                            bbb = abo+1
                            print("---------------------3B---------------------")
                        else:
                            sumFP[Adict[abo+1][0]]+=18.7
                            sumFP[hp[0][1]]+=-3
                            if bbb > 0:
                                sumFP[Adict[bbb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                away+=1
                            if bb > 0:
                                sumFP[Adict[bb][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                bb = 0
                                ins+=1
                                away+=1
                            if b > 0:
                                sumFP[Adict[b][0]]+=3.2
                                sumFP[Adict[abo+1][0]]+=3.5
                                sumFP[hp[0][1]]+=-3
                                b = 0
                                ins+=1
                                away+=1
                            ins+=1
                            away+=1
                            print("---------------------HR---------------------")
                        if ins > 4:
                            if len(hp) == 2:
                                hss['home'] = home
                                hss['away'] = away
                                hstart.append(hp[0])
                                hp.pop(0)
                                print('Home SP baaad game')
                        elif away - home > 4:
                            if len(hp) == 2:
                                hss['home'] = home
                                hss['away'] = away
                                hstart.append(hp[0])
                                hp.pop(0)
                                print('Home SP Rocked')
                        labo+=1
                        abo+=1
                    #print('--------------------------AWAY AB Stats ^^^^^------------------')
            else:
                print('-------------------------------------Bottom-Of-The-'+str((inning/2)+.5)+'-----------------------------')
                #Current hBvaP
                b = 0
                bb = 0
                bbb = 0
                out = 0
                shbo = hbo
                ins = 0
                while out < 3:
                    if hbo == 9:
                        hbo = 0
                    while hbo < 9:
                        if out == 3:
                            break
                        #lhbo.append(hbo)
                        #SO prob
                        so = (((Hdict[hbo+1][6])*ap[0][7])/Aso)/((((Hdict[hbo+1][6])*ap[0][7])/Aso)+(((1-Hdict[hbo+1][6])*(1-ap[0][7]))/(1-Aso)))
                        #Field out prob
                        ot = (((Hdict[hbo+1][7])*ap[0][8])/Afo)/((((Hdict[hbo+1][7])*ap[0][8])/Afo)+(((1-Hdict[hbo+1][7])*(1-ap[0][8]))/(1-Afo)))
                        #walk prob
                        walk = (((Hdict[hbo+1][8])*ap[0][9])/Abb)/((((Hdict[hbo+1][8])*ap[0][9])/Abb)+(((1-Hdict[hbo+1][8])*(1-ap[0][9]))/(1-Abb)))
                        #HBP prob
                        hbp = (((Hdict[hbo+1][9])*ap[0][10])/Ahbp)/((((Hdict[hbo+1][9])*ap[0][10])/Ahbp)+(((1-Hdict[hbo+1][9])*(1-ap[0][10]))/(1-Ahbp)))
                        #single prob
                        sing = (((Hdict[hbo+1][10])*ap[0][11])/Asing)/((((Hdict[hbo+1][10])*ap[0][11])/Asing)+(((1-Hdict[hbo+1][10])*(1-ap[0][11]))/(1-Asing)))
                        #double prob
                        dbl = (((Hdict[hbo+1][11])*ap[0][12])/Adbl)/((((Hdict[hbo+1][11])*ap[0][12])/Adbl)+(((1-Hdict[hbo+1][11])*(1-ap[0][12]))/(1-Adbl)))
                        #triple prob
                        trp = (((Hdict[hbo+1][12])*ap[0][13])/Atrp)/((((Hdict[hbo+1][12])*ap[0][13])/Atrp)+(((1-Hdict[hbo+1][12])*(1-ap[0][13]))/(1-Atrp)))
                        #hr prob
                        hr = (((Hdict[hbo+1][13])*ap[0][14])/Ahr)/((((Hdict[hbo+1][13])*ap[0][14])/Ahr)+(((1-Hdict[hbo+1][13])*(1-ap[0][14]))/(1-Ahr)))
                        #Total not equal to one all hitters, attempt to smooth this out --- If not some hitters HR rate doubles
                        tot = (so + ot + walk + hbp + sing + dbl + trp + hr)
                        err = ((1 - tot)/8)
                        so = (err+so)
                        ot = (err+ot)
                        walk = (err+walk)
                        hbp = (err+hbp)
                        sing = (err+sing)
                        dbl = (err+dbl)
                        trp = (err+trp)
                        hr = (err+hr)
                        onBase = random.uniform(0,1)
                        print(ap[0][1])
                        print('Home: '+str(home)+' Away: '+str(away))
                        print('1B: '+str(b)+' 2B: '+str(bb)+' 3B: '+str(bbb))
                        print('Out: '+str(out))
                        print('hbo:'+ str(hbo))
                        if onBase <= so:
                            sumFP[ap[0][1]]+=4
                            out+=1
                            #hbo+=1
                            print('---------------------SO---------------------')
                        elif onBase <= (so + ot):
                            sumFP[ap[0][1]]+=1
                            out+=1
                            #hbo+=1
                            print('---------------------Batter Out---------------------')
                            if b > 0:
                                if out < 2:
                                    if onBase <= (so + .04):
                                        sumFP[ap[0][1]]+=1
                                        out+=1
                                        b = 0
                                        if bbb > 0:
                                            sumFP[Hdict[bbb][0]]+=3.2
                                            sumFP[ap[0][1]]+=-3
                                            bbb = 0
                                            ins+=1
                                            home+=1
                                        bbb = bb
                                        bb = 0
                                        print('---------------------Double Play---------------------')
                        elif onBase <= (so + ot + walk):
                            sumFP[Hdict[hbo+1][0]]+=3
                            print('---------------------Walk---------------------')
                            if b > 0:
                                if bb > 0:
                                    if bbb > 0:
                                        sumFP[Hdict[hbo+1][0]]+=3.5
                                        sumFP[Hdict[bbb][0]]+=3.2
                                        sumFP[ap[0][1]]+=-3
                                        bbb = bb
                                        ins+=1
                                        home+=1
                                    else:
                                        bbb = bb
                                else:
                                    bbb = bb
                                bb = b
                                b = hbo+1
                            else:
                                b = hbo+1
                        elif onBase <= (so + ot + walk + hbp):
                            sumFP[Hdict[hbo+1][0]]+=3
                            print('---------------------HBP---------------------')
                            if b > 0:
                                if bb > 0:
                                    if bbb > 0:
                                        sumFP[Hdict[hbo+1][0]]+=3.5
                                        sumFP[Hdict[bbb][0]]+=3.2
                                        sumFP[ap[0][1]]+=-3
                                        bbb = bb
                                        ins+=1
                                        home+=1
                                    else:
                                        bbb = bb
                                else:
                                    bbb = bb
                                bb = b
                                b = hbo+1
                            else:
                                b = hbo+1
                        elif onBase <= (so + ot + walk + hbp + sing):
                            sumFP[Hdict[hbo+1][0]]+=3
                            #Runners on Base advance 1 or 2+ bags
                            adv = random.uniform(0,1)
                            if bbb > 0:
                                sumFP[Hdict[bbb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                home+=1
                            if bb > 0:
                                if adv > Hdict[bb][15]:
                                    sumFP[Hdict[bb][0]]+=3.2
                                    sumFP[Hdict[hbo+1][0]]+=3.5
                                    sumFP[ap[0][1]]+=-3
                                    bb = 0
                                    ins+=1
                                    home+=1
                                else:
                                    bbb = bb
                                    bb = 0
                            if b > 0:
                                if bbb > 0:
                                    bb = b
                                    b = 0
                                elif adv > Hdict[b][15]:
                                    bbb = b
                                    b = 0
                                else:
                                    bb = b
                                    b = 0
                            b = hbo+1
                            print('---------------------Single---------------------')
                        elif onBase <= (so + ot + walk + hbp + sing + dbl):
                            sumFP[Hdict[hbo+1][0]]+=6
                            #Runners on Base advance 1 or 2+ bags
                            adv = random.uniform(0,1)
                            if bbb > 0:
                                sumFP[Hdict[bbb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                home+=1
                            if bb > 0:
                                sumFP[Hdict[bb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bb = 0
                                ins+=1
                                home+=1
                            if b > 0:
                                if adv > (Hdict[b][15] * 1.15):
                                    sumFP[Hdict[b][0]]+=3.2
                                    sumFP[Hdict[hbo+1][0]]+=3.5
                                    sumFP[ap[0][1]]+=-3
                                    b = 0
                                    ins+=1
                                    home+=1
                                else:
                                    bbb = b
                                    b = 0
                            bb = hbo+1
                            print("---------------------2B---------------------")
                        elif onBase <= (so + ot + walk + hbp + sing + dbl + trp):
                            sumFP[Hdict[hbo+1][0]]+=9
                            if bbb > 0:
                                sumFP[Hdict[bbb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                home+=1
                            if bb > 0:
                                sumFP[Hdict[bb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bb = 0
                                ins+=1
                                home+=1
                            if b > 0:
                                sumFP[Hdict[b][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                b = 0
                                ins+=1
                                home+=1
                            bbb = hbo+1
                            print("---------------------3B---------------------")
                        else:
                            sumFP[Hdict[hbo+1][0]]+=18.7
                            sumFP[ap[0][1]]+=-3
                            if bbb > 0:
                                sumFP[Hdict[bbb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bbb = 0
                                ins+=1
                                home+=1
                            if bb > 0:
                                sumFP[Hdict[bb][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                bb = 0
                                ins+=1
                                home+=1
                            if b > 0:
                                sumFP[Hdict[b][0]]+=3.2
                                sumFP[Hdict[hbo+1][0]]+=3.5
                                sumFP[ap[0][1]]+=-3
                                b = 0
                                ins+=1
                                home+=1
                            ins+=1
                            home+=1
                            print("---------------------HR---------------------")
                        if ins > 4:
                            if len(ap) == 2:
                                ass['home'] = home
                                ass['away'] = away
                                astart.append(ap[0])
                                ap.pop(0)
                                print('Away SP baaad game')
                                print(ins)
                        elif home - away > 4:
                            if len(ap) == 2:
                                ass['home'] = home
                                ass['away'] = away
                                astart.append(ap[0])
                                ap.pop(0)
                                print('Away SP Rocked')
                                print(home - away)
                        lhbo+=1    
                        hbo+=1
            #Clear Bases for new inning
            b=[]
            bb=[]
            bbb=[]
            ins = 0
            #Awards QS after 6th Inning Played
            #hqs = 0
            if inning == 10:
                if hp[0][1] == hsp[0]:
                    if away < 4:
                        sumFP[hp[0][1]]+=4
                        hss['away'] = away
                        hss['home'] = home
                        hqs+=1
                        print('HOME QS!!!!!!')
            #aqs = 0
            if inning == 11:
                if ap[0][1] == asp[0]:
                    if home < 4:
                        sumFP[ap[0][1]]+=4
                        ass['home'] = home
                        ass['away'] = away
                        aqs+=1
                        print('Away QS!!!!!!')
            #Removes bonus if needed
            if inning == 12:
                if hp[0][1] == hsp[0]:
                    #if hss['away'] < 4:
                    if hqs == 1:
                        if away > 3:
                            sumFP[hp[0][1]]+=-4
                            print('HOME SP LOST QS!!!!!!')
            if inning == 13:
                if ap[0][1] == asp[0]:
                    #if ass['home'] < 4:
                    if aqs == 1:
                        if home > 3:
                            sumFP[ap[0][1]]+=-4
                            print('Away SP LOST QS!!!!!!')
            #Pulls pitcher over 24 batters faced
            if labo > (hp[0][15])+3:
                if len(hp) == 2:
                    hss['away'] = away
                    hss['home'] = home
                    hstart.append(hp[0])
                    hp.pop(0)
                    print('Home SP Batter Limit')
            if lhbo > (ap[0][15])+3:
                if len(ap) == 2:
                    ass['home'] = home
                    ass['away'] = away
                    astart.append(ap[0])
                    ap.pop(0)
                    print('Away SP Batter Limit')
            #Pull pitcher if runs over 5 append BP to hp from
            if away > 5:
                if len(hp) == 2:
                    hss['away'] = away
                    hss['home'] = home
                    hstart.append(hp[0])
                    hp.pop(0)
            if home > 5:
                if len(ap) == 2:
                    ass['home'] = home
                    ass['away'] = away
                    astart.append(ap[0])
                    ap.pop(0)
            #Pull pitcher after 7 IP
            if inning >= 12:
                if len(hp) == 2:
                    hss['away'] = away
                    hss['home'] = home
                    hstart.append(hp[0])
                    hp.pop(0)
            if inning >= 13:
                if len(ap) == 2:
                    ass['home'] = home
                    ass['away'] = away
                    astart.append(ap[0])
                    ap.pop(0)
            #End game if home ahead
            if inning == 16:
                if home > away:
                    inning += 18
            #advance inning
            inning+=1
        #Advance to next game sim
        j+=1
        #push final game score to counter
        scores[h[1][3]] = home + scores[h[1][3]]
        scores[a[1][3]] = away + scores[a[1][3]]
        #awards win bonus if SP was ahead when pulled in 7th and team wins game
        if home > away:
            if hss['home'] > hss['away']:
                if away < hss['home']:
                    sumFP[hstart[0][1]]+=6
                    print('Home SP Win')
        else:
            if ass['away'] > ass['home']:
                if home < ass['away']:
                    sumFP[astart[0][1]]+=6
                    print('Away SP Win')
        gs = 0
        print('--------------------------------------------------------------------------------------------------')
        print('--------------------------------------------GAME-END----------------------------------------------')
        print('--------------------------------------------------------------------------------------------------')
        #push player game scores to counter
        for u in sumFP:
            gameFP[u].append(sumFP[u])
            gs+=1
    #All games simmed n times, advances to next round
    sim+=1
# Out:
# 3500
# [[nan, 'Tony Gonsolin', 'P', 'LAD', 'MIL', 'LAD', 'MIL@LAD', 0.2404255319, 0.5255319149, 0.07021276596, 0.008510638298, 0.08723404255, 0.03829787234, 0.006382978723, 0.02340425532, 21.0, nan], [nan, 'LAD BP', 'P', 'LAD', 'MIL', 'LAD', 'MIL@LAD', 0.2598013591, 0.4521693675, 0.08050182959, 0.01202300052, 0.122843701, 0.04391008887, 0.002090956613, 0.02665969681, 50.0, nan]]
# [[nan, 'Corbin Burnes', 'P', 'MIL', 'LAD', 'LAD', 'MIL@LAD', 0.3196581197, 0.4256410256, 0.06837606838, 0.01709401709, 0.1025641026, 0.03247863248, 0.006837606838, 0.02735042735, 24.0, nan], [nan, 'MIL BP', 'P', 'MIL', 'LAD', 'LAD', 'MIL@LAD', 0.2616984402, 0.443096476, 0.08261120739, 0.01675332178, 0.1317157712, 0.03408434431, 0.004043905257, 0.0259965338, 50.0, nan]]
# -------------------------------------Top-Of-The-1.0-----------------------------
# Tony Gonsolin
# Home: 0 Away: 0
# 1B: 0 2B: 0 3B: 0
# Out: 0
# abo:0
# ---------------------HR---------------------
# Tony Gonsolin
# Home: 0 Away: 1
# ...

# %%
final = {}
avg = 0
for row in stats:
    key = row[1]
    final[key] = gameFP[names[avg]]
    print(names[avg]+' '+str(sum(final[names[avg]])/ts))
    avg+=1

# %%
scr = 0
while scr < len(tm):
    print(tm[scr]+": "+str(scores[tm[scr]]/ts))
    scr+=1

# %%
templist = []
pl = 0
while pl < len(final.keys()):
    Table_dict={'Name': list(final.keys())[pl], 'FP': str(sum(final[names[pl]])/ts)}
    templist.append(Table_dict)
    df = pd.DataFrame(templist)
    pl+=1
df.to_csv(f'C:\\Users\\Steven\\Desktop\\MLBsim.csv')
